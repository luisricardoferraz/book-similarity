# %%
import nltk
nltk.download('rslp')

import pandas as pd
from pandas import DataFrame
import numpy as np

from nltk.stem import RSLPStemmer
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     /Users/luisricardoferraz/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
#Count number of characters in each string
def countCharactersInEachString(df, column):
    charactersCount = []
    for synopsis in df[column]:
        charactersCount.append(len(str(synopsis)))
    return charactersCount

#Count number of words in each string
def countWordsInEachString(df, column):
    wordsCount = []
    for synopsis in df[column]:
        words = word_tokenize(str(synopsis))
        wordsCount.append(len(words))
    return wordsCount

#Extract some basic statistics about synopsis
def extractBasicStatisticsAboutSynopsis(arrayOfSizes):
    synopsisLength = np.array(arrayOfSizes)
    basicStatistics = "\t"   
    basicStatistics += "Arithmetic Mean: " + str(np.mean(synopsisLength)) + "\n\t"
    basicStatistics += "Median: " + str(np.median(synopsisLength)) + "\n\t"
    basicStatistics += "Highest Value: " + str(np.max(synopsisLength)) + "\n\t"
    basicStatistics += "Lowest Value: " + str(np.min(synopsisLength)) + "\n\t"
    basicStatistics += "Mid-range: " + str((np.max(synopsisLength)-np.min(synopsisLength))/2) + "\n\t"
    basicStatistics += "Variance: " + str(np.var(synopsisLength,ddof=1)) + "\n\t"
    basicStatistics += "Standard Deviation: " + str(np.std(synopsisLength,ddof=1)) + "\n\t"
    return basicStatistics

def extractPercentilesAboutSynopsis(arrayOfSizes):
    synopsisLength = np.array(arrayOfSizes)
    percentiles = "Percentiles: " + "\n\t"
    count = 0.5
    while count <= 100:
        percentiles += "Percentile " + str(count) + ": " + str(np.percentile(arrayOfSizes,count)) + "\n\t"
        count += 0.5
    return percentiles

#Extract some statistics about this Dataset
def extractStatisticsFromSynopsis(dataframe, title, column):
    log = title + "\n\n"
    log += "Shape of Dataset: " + str(dataframe.shape[0]) + " rows and " + str(dataframe.shape[1]) + " columns" + "\n\n"
    log += "Statistics of Synopsis Length (Characters):" + "\n"
    charactersCount = countCharactersInEachString(dataframe, column)
    log += extractBasicStatisticsAboutSynopsis(charactersCount) + "\n"
    log += extractPercentilesAboutSynopsis(charactersCount) + "\n"
    log += "Statistics of Synopsis Length (Words):" + "\n"
    wordsCount = countWordsInEachString(dataframe, column)
    log += extractBasicStatisticsAboutSynopsis(wordsCount) + "\n"
    log += extractPercentilesAboutSynopsis(wordsCount) + "\n"
    return log

# %%
st = RSLPStemmer()
def applyStemmingOnSynopsis(text):
    stringAfterStemming = []
    for token in word_tokenize(text):
        stringAfterStemming.append(st.stem(token))
    return " ".join(stringAfterStemming)

# %%
filePath = '/Users/luisricardoferraz/book-similarity/test/tutorial/tutorial/spiders/synopsis-preprocessing/'

# %%
#Import CSV file to a DataFrame
df = pd.read_csv(filePath+'dataSetComPosTaggingDepoisDaRemocaoDeStopwords.csv')
df = df.drop(['Unnamed: 0'],1)

# %%
df['stemmedSynopsis'] = df['synopsisWithoutStopwords']

# %%
df['stemmedSynopsis'] = [applyStemmingOnSynopsis(text) for text in df['stemmedSynopsis']]

# %%
df.to_csv(filePath+'dataSetDepoisDoStemming.csv')
with open(filePath+'logDataSetDepoisDoStemming.txt','w') as log:
    log.write(extractStatisticsFromSynopsis(df, "Statistics of Dataset - Stemming Applied to Synopsis", 'stemmedSynopsis'))

# %%
df
# Out:
#                                                   titulo  \
# 0                                        Tapete Vermelho
# 1                                                 Hunter
# 2                                                   Cage
# 3                                         Espere Por Mim
# 4                                                    Vox
# 5                                                   Ayra
# 6                                         Amor Plus Size
# 7                                          O Sal da Vida
# 8                                                Aliança
# 9                                    A Dança dos Dragões
# 10                                  Diário de Uma Paixão
# 11                                       Luta de Valetes
# 12                                      Mulher-Maravilha
# 13                                Onde o Amor Se Esconde
# 14                  Mulher-Maravilha: Sementes da Guerra
# 15                                    Todos contra todos
# 16                       A Verdade Sobre Amores e Duques
# 17                        As Batidas Perdidas do Coração
# 18                                 A batalha das Ardenas
# 19                                  Churchill - Uma vida
# 20                     O Diário Secreto de Lizzie Bennet
# 21                            Cartas Para Uma Falsa Dama
# 22                                        Falsas Imagens
# 23                                      Dezenove Minutos
# 24                                        Encanto Mortal
# 25                                  Sintonia de Corações
# 26                                A Corrida de Escorpião
# 27                                          Piadas Nerds
# 28                                   Natureza Apaixonada
# 29                                        Doces Mentiras
# ...                                                  ...
# 10140                                    Os Imortalistas
# 10141                     1565: Enquanto o Brasil Nascia
# 10142                                    Procurando Gobi
# 10143                      O Mau Exemplo de Cameron Post
# 10144                         Livro de Ouro da Mitologia
# 10145                       Um Planeta em Seu Giro Veloz
# 10146                     O Livro de Ouro das Revoluções
# 10147                               Os Arquivos da Magia
# 10148  The Underground Railroad: Os Caminhos Para a L...
# 10149                        Tasty. As Melhores Receitas
# 10150                                    A Arte de Viver
# 10151                                 Coisas Melequentas
# 10152                                    Beren e Lúthien
# 10153                        Guinness World Records 2019
# 10154                           As Madonas de Leningrado
# 10155                                  A Caminho de Casa
# 10156                      1924 - O Ano Que Criou Hitler
# 10157     Bff Girls - O Começo De Uma História Pra Ficar
# 10158                               Cuida do meu coração
# 10159                                    Apenas um Toque
# 10160                                            Aaahhh!
# 10161                                     Maquiagem Teen
# 10162                                 Coisas Arrepiantes
# 10163                 O guia definitivo para o pós-parto
# 10164                                             Use-Me
# 10165                                  Inexplicável Amor
# 10166                                         Libertados
# 10167                                          Renegados
# 10168                                   Por Trás da Fama
# 10169                                          Para Você
#
#                                                  sinopse  \
# 0      [{'token': 'uma', 'poss': 'DI0', 'lemma': 'um'...
# 1      [{'token': 'resgate', 'poss': 'NCMS', 'lemma':...
# 2      [{'token': 'cage', 'poss': 'VMI', 'lemma': '<u...
# 3      [{'token': 'quebrado', 'poss': 'VMP', 'lemma':...
# 4      [{'token': 'uma', 'poss': 'DI0', 'lemma': 'um'...
# 5      [{'token': 'as', 'poss': 'DA0', 'lemma': 'o'},...
# 6      [{'token': 'maitê', 'poss': 'NCFP', 'lemma': '...
# 7      [{'token': 'existe', 'poss': 'VMI', 'lemma': '...
# 8      [{'token': 'um', 'poss': 'DI0', 'lemma': 'um'}...
# 9      [{'token': 'as', 'poss': 'DA0', 'lemma': 'o'},...
# 10     [{'token': 'duke', 'poss': 'NCMS', 'lemma': '<...
# 11     [{'token': 'o', 'poss': 'DA0', 'lemma': 'o'}, ...
# 12     [{'token': 'diana', 'poss': 'NCFS', 'lemma': '...
# 13     [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
# 14     [{'token': 'antes', 'poss': 'RG', 'lemma': 'an...
# 15     [{'token': 'podemos', 'poss': 'VMI', 'lemma': ...
# 16     [{'token': 'henry', 'poss': 'NCMS', 'lemma': '...
# 17     [{'token': 'viviane', 'poss': 'VMI', 'lemma': ...
# 18     [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
# 19     [{'token': 'escrito', 'poss': 'VMP', 'lemma': ...
# 20     [{'token': 'lizzie', 'poss': 'VMI', 'lemma': '...
# 21     [{'token': 'ainda', 'poss': 'RG', 'lemma': 'ai...
# 22     [{'token': 'autoras', 'poss': 'NCFP', 'lemma':...
# 23     [{'token': 'sterling', 'poss': 'NCMS', 'lemma'...
# 24     [{'token': 'o', 'poss': 'DA0', 'lemma': 'o'}, ...
# 25     [{'token': 'uma', 'poss': 'DI0', 'lemma': 'um'...
# 26     [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
# 27     [{'token': 'livro', 'poss': 'NCMS', 'lemma': '...
# 28     [{'token': 'união', 'poss': 'NCFS', 'lemma': '...
# 29     [{'token': 'para', 'poss': 'SPS', 'lemma': 'pa...
# ...                                                  ...
# 10140  [{'token': 'é', 'poss': 'VMI', 'lemma': 'ser'}...
# 10141  [{'token': 'este', 'poss': 'DD0', 'lemma': 'es...
# 10142  [{'token': 'encontrando', 'poss': 'VMG', 'lemm...
# 10143  [{'token': 'quando', 'poss': 'RG', 'lemma': 'q...
# 10144  [{'token': 'altares', 'poss': 'NCMP', 'lemma':...
# 10145  [{'token': 'um', 'poss': 'DI0', 'lemma': 'um'}...
# 10146  [{'token': 'de', 'poss': 'SPS', 'lemma': 'de'}...
# 10147  [{'token': 'newt', 'poss': 'NCMS', 'lemma': '<...
# 10148  [{'token': 'cora', 'poss': 'NCFS', 'lemma': 'c...
# 10149  [{'token': 'você', 'poss': 'PP3', 'lemma': 'vo...
# 10150  [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
# 10151  [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
# 10152  [{'token': 'o', 'poss': 'DA0', 'lemma': 'o'}, ...
# 10153  [{'token': 'nova', 'poss': 'AQ0', 'lemma': 'no...
# 10154  [{'token': 'guerra', 'poss': 'NCFS', 'lemma': ...
# 10155  [{'token': 'bella', 'poss': 'VMI', 'lemma': '<...
# 10156  [{'token': 'antes', 'poss': 'RG', 'lemma': 'an...
# 10157  [{'token': 'você', 'poss': 'PP3', 'lemma': 'vo...
# 10158  [{'token': 'não', 'poss': 'RN', 'lemma': 'não'...
# 10159  [{'token': 'quando', 'poss': 'RG', 'lemma': 'q...
# 10160  [{'token': 'um', 'poss': 'DI0', 'lemma': 'um'}...
# 10161  [{'token': 'ramon', 'poss': 'NCFS', 'lemma': '...
# 10162  [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
# 10163  [{'token': 'o', 'poss': 'DA0', 'lemma': 'o'}, ...
# 10164  [{'token': 'a', 'poss': 'DA0', 'lemma': 'o'}, ...
# 10165  [{'token': 'nunca', 'poss': 'RG', 'lemma': 'nu...
# 10166  [{'token': 'sawyer', 'poss': 'NCMS', 'lemma': ...
# 10167  [{'token': 'o', 'poss': 'DA0', 'lemma': 'o'}, ...
# 10168  [{'token': 'james', 'poss': 'NCMP', 'lemma': '...
# 10169  [{'token': 'em', 'poss': 'SPS', 'lemma': 'em'}...
#
#                                 synopsisWithoutStopwords  adjective_after  \
# 0      jovem garota brasileira resolve aventurar curs...                6
# 1      resgate primeira palavra ouvi tiros cessaram f...                6
# 2      substantivo cela prisão verbo prender enjaular...                5
# 3      quebrado irritado abandonado sentia dias lutav...                5
# 4      atual próxima dias luta feminina silêncio pode...                4
# 5      histórias contos fadas crianças ouvem fizeram ...                2
# 6      passos garota linda dezessete anos quilos pass...               11
# 7      existe forma leveza graça simples fato existir...               12
# 8      thriller luta secreta bem mal pessoas habilida...                9
# 9      crônicas gelo fogo personagens presentes quint...               18
# 10     homem simples vida modesta amou coração sufici...               20
# 11     oitavo volume injeta tensão fantasia universo ...               11
# 12     diana conhecida mulher maravilha criada amadas...               24
# 13     início século xx jovem glória sonha amor contr...               16
# 14     tornar mulher maravilha diana filha deusa dian...                7
# 15     podemos viver paraíso passamos inferno brasil ...               11
# 16     henry duque anseia vida ordenada previsível ún...                8
# 17     acaba perder pai mãe depressão vê obrigada ass...                8
# 18     primeiras horas dia dezembro lançou última gra...               19
# 19     escrito biógrafo oficial historiador consagrad...               11
# 20     jovem estudante comunicação resolve fazer proj...               18
# 21     recém casado conde deixou esposa defender duca...                6
# 22     autoras usa melodia coração sedução implacável...               12
# 23     cidadezinha comum interior acontece dia quietu...                9
# 24     passado envolto segredos morte trágica pais me...               14
# 25     receita apaixonante pegue dose d crítica culin...               11
# 26     pequena ilha cavaleiros bravos suficiente comp...               21
# 27     livro formato bolso ilustrações ruas traz comp...                0
# 28     união sentimentos cate acabou ouvindo conversa...               11
# 29     manter casamento esposa cativada casou tímida ...               13
# ...                                                  ...              ...
# 10140  nova rumores vizinhança chegada mulher mística...               17
# 10141  livro história inúmeros improváveis personagen...               10
# 10142  encontrando relato milagroso atravessa longos ...               15
# 10143  pais morrem acidente carro primeira coisa sent...               20
# 10144  altares ruíram templos perderam areias tempo r...               13
# 10145  unicórnio menino vento juntos velocidade charl...                5
# 10146  revoltas populares golpes militares guerras ci...               17
# 10147  tina amados heróis animais fantásticos habitam...               21
# 10148  cora escrava plantação algodão década conhece ...                5
# 10149  conhece popular canal culinária une pessoas mu...                8
# 10150  tempos difíceis urgência entender mundo questõ...                7
# 10151  livro premiado autor apresenta série coisas pe...                5
# 10152  conto tornou elemento fundamental evolução mit...               27
# 10153  nova edição famoso livro recordes mundo encont...                8
# 10154  guerra amor vida unem drama sensível visita le...               13
# 10155  linda cadelinha vira lata adotou lucas opção a...                9
# 10156  holocausto segunda guerra mundial momento deci...               13
# 10157  sabe girls chance aproximar trio vai ficar sab...                1
# 10158  adianta enganar ano começa carnaval conseguiu ...                6
# 10159  adam colocou olhos doce esperava ficar fascina...               13
# 10160  grande barulho ecoou redor mundo trazendo caos...                2
# 10161  amorim cresceu pequena cidade andorinha pequen...                4
# 10162  livro conhecido escritor apresenta série coisa...                9
# 10163  dr especialista neozelandês saúde mulher foca ...               13
# 10164  vida cole girou torno hóquei soube crescesse j...               16
# 10165  grito vitória dor olhavam extasiados fim enxer...               11
# 10166  quer ter própria vida quer esquecer dia tragéd...                6
# 10167  amor compartilhamos tipo esquece tipo quer esq...                1
# 10168  sabia imprensa capaz fazer vida intrigas boato...                9
# 10169  livro envolvido temas emocionantes farão coraç...               22
#
#        conjunction_after  determiner_after  noun_after  pronoun_after  \
# 0                      0                 0          21              0
# 1                      0                 0          23              0
# 2                      0                 0          21              0
# 3                      0                 0          19              0
# 4                      0                 0          25              0
# 5                      0                 0          17              0
# 6                      0                 0          28              0
# 7                      0                 0          26              0
# 8                      0                 0          23              0
# 9                      0                 0          59              0
# 10                     0                 0          50              0
# 11                     0                 0          35              0
# 12                     0                 0          67              0
# 13                     0                 0          44              0
# 14                     0                 0          24              0
# 15                     0                 0          38              0
# 16                     0                 0          30              0
# 17                     0                 0          25              0
# 18                     0                 0          36              0
# 19                     0                 0          28              0
# 20                     0                 0          46              0
# 21                     0                 0          18              0
# 22                     0                 0          39              0
# 23                     0                 0          35              0
# 24                     0                 0          40              0
# 25                     0                 0          20              0
# 26                     0                 0          63              0
# 27                     0                 0           9              0
# 28                     0                 0          34              0
# 29                     0                 0          30              0
# ...                  ...               ...         ...            ...
# 10140                  0                 0          52              0
# 10141                  0                 0          25              0
# 10142                  0                 0          33              0
# 10143                  0                 0          38              0
# 10144                  0                 0          32              0
# 10145                  0                 0          24              0
# 10146                  0                 0          38              0
# 10147                  0                 0          52              0
# 10148                  0                 0          23              0
# 10149                  0                 0          29              0
# 10150                  0                 0          26              0
# 10151                  0                 0          15              0
# 10152                  0                 0          77              0
# 10153                  0                 0          15              0
# 10154                  0                 0          41              0
# 10155                  0                 0          39              0
# 10156                  0                 0          46              0
# 10157                  0                 0          16              0
# 10158                  0                 0          20              0
# 10159                  0                 0          36              0
# 10160                  0                 0          14              0
# 10161                  0                 0          26              0
# 10162                  0                 0          31              0
# 10163                  0                 0          54              0
# 10164                  0                 0          47              0
# 10165                  0                 0          45              0
# 10166                  0                 0          15              0
# 10167                  0                 0          11              0
# 10168                  0                 0          28              0
# 10169                  0                 0          92              0
#
#        adverb_after  adposition_after  verb_after  number_after  date_after  \
# 0                 0                 0          15             0           0
# 1                 0                 0          24             0           0
# 2                 0                 0          21             0           0
# 3                 0                 0          27             0           0
# 4                 0                 0          20             0           0
# 5                 0                 0          23             0           0
# 6                 0                 0          14             0           0
# 7                 0                 0          14             0           0
# 8                 0                 0          14             0           0
# 9                 0                 0          25             0           0
# 10                0                 0          29             0           0
# 11                0                 0          11             0           0
# 12                0                 0          26             0           0
# 13                0                 0          20             0           0
# 14                0                 0          16             0           0
# 15                0                 0          17             0           0
# 16                0                 0          24             0           0
# 17                0                 0          28             0           0
# 18                0                 0          12             0           0
# 19                0                 0          10             0           0
# 20                0                 0          24             0           0
# 21                0                 0          13             0           0
# 22                0                 0          31             0           0
# 23                0                 0          21             0           0
# 24                0                 0          28             0           0
# 25                0                 0          17             0           0
# 26                0                 0          29             0           0
# 27                0                 0           2             0           0
# 28                0                 0          40             0           0
# 29                0                 0          33             0           0
# ...             ...               ...         ...           ...         ...
# 10140             0                 0          16             0           0
# 10141             0                 0           8             0           0
# 10142             0                 0          25             0           0
# 10143             0                 0          35             0           0
# 10144             0                 0          12             0           0
# 10145             0                 0          18             0           0
# 10146             0                 0          11             0           0
# 10147             0                 0          13             0           0
# 10148             0                 0          10             0           0
# 10149             0                 0          14             0           0
# 10150             0                 0          16             0           0
# 10151             0                 0           7             0           0
# 10152             0                 0          33             0           0
# 10153             0                 0          10             0           0
# 10154             0                 0          15             0           0
# 10155             0                 0          17             0           0
# 10156             0                 0          23             0           0
# 10157             0                 0          11             0           0
# 10158             0                 0          20             0           0
# 10159             0                 0          30             0           0
# 10160             0                 0           7             0           0
# 10161             0                 0           8             0           0
# 10162             0                 0          18             0           0
# 10163             0                 0          28             0           0
# 10164             0                 0          35             0           0
# 10165             0                 0          32             0           0
# 10166             0                 0          17             0           0
# 10167             0                 0          12             0           0
# 10168             0                 0          19             0           0
# 10169             0                 0          76             0           0
#
#        interjection_after  punctuation_after  unknown_after  total_after  \
# 0                       0                  0              0           42
# 1                       0                  0              0           53
# 2                       0                  0              0           47
# 3                       0                  0              0           51
# 4                       0                  0              0           49
# 5                       0                  0              0           42
# 6                       0                  0              0           53
# 7                       0                  0              0           52
# 8                       0                  0              0           46
# 9                       0                  0              0          102
# 10                      0                  0              0           99
# 11                      0                  0              0           57
# 12                      0                  0              0          117
# 13                      0                  0              0           80
# 14                      0                  0              0           47
# 15                      0                  0              0           66
# 16                      0                  0              0           62
# 17                      0                  0              0           61
# 18                      0                  0              0           67
# 19                      0                  0              0           49
# 20                      0                  0              0           88
# 21                      0                  0              0           37
# 22                      0                  0              0           82
# 23                      0                  0              0           65
# 24                      0                  0              0           82
# 25                      0                  0              0           48
# 26                      0                  0              0          113
# 27                      0                  0              0           11
# 28                      0                  0              0           85
# 29                      0                  0              0           76
# ...                   ...                ...            ...          ...
# 10140                   0                  0              0           85
# 10141                   0                  0              0           43
# 10142                   0                  0              0           73
# 10143                   0                  0              0           93
# 10144                   0                  0              0           57
# 10145                   0                  0              0           47
# 10146                   0                  0              0           66
# 10147                   0                  0              0           86
# 10148                   0                  0              0           38
# 10149                   0                  0              0           51
# 10150                   0                  0              0           49
# 10151                   0                  0              0           27
# 10152                   0                  0              0          137
# 10153                   0                  0              0           33
# 10154                   0                  0              0           69
# 10155                   0                  0              0           65
# 10156                   0                  0              0           82
# 10157                   0                  0              0           28
# 10158                   0                  0              0           46
# 10159                   0                  0              0           79
# 10160                   0                  0              0           23
# 10161                   0                  0              0           38
# 10162                   0                  0              0           58
# 10163                   0                  0              0           95
# 10164                   0                  0              0           98
# 10165                   0                  0              0           88
# 10166                   0                  0              0           38
# 10167                   0                  0              0           24
# 10168                   0                  0              0           56
# 10169                   0                  0              0          190
#
#                                          stemmedSynopsis
# 0      jov garot brasil resolv aventur curs ingl exte...
# 1      resgat prim palavr ouv tir cess fer tir ouv le...
# 2      substan cel pris verb prend enjaul ment fácel ...
# 3      quebr irrit abandon sent dia lut monstr viv re...
# 4      atual próx dia lut feminin silênci pod ser ens...
# 5      histór cont fad crianç ouv fiz sent form desco...
# 6      pass garot lind dezesset ano quil pass infânc ...
# 7      exist form lev graç simpl fat exist vai ocup s...
# 8      thrill lut secret bem mal pesso habil espec ex...
# 9      crôn gel fog person pres quint volum séri danç...
# 10     hom simpl vid modest amou coraçã sufici clín r...
# 11     oitav volum injet tens fantas univers delir cr...
# 12     dian conhec mulh maravilh cri am person histór...
# 13     iníci sécul xx jov glór sonh am contr amig des...
# 14     torn mulh maravilh dian filh deus dian desej p...
# 15     pod viv paraís pass infern brasil terr furacã ...
# 16     henry duqu anse vid orden previs únic ajud mãe...
# 17     acab perd pai mãe depress vê obrig assum contr...
# 18     prim hor dia dezembr lanç últ grand ofens ali ...
# 19     escrit biógraf ofic histori consagr gilbert li...
# 20     jov estud comunic resolv faz projet faculdad p...
# 21     recém cas cond deix esp defend duc bretanh ano...
# 22     autor usa melod coraçã seduç implac ador jog s...
# 23     cidad comum interi acontec dia quietud abal te...
# 24     pass envolt segred mort trág pal mei verdad ma...
# 25     receit apaixon peg dos d crít culinár relacion...
# 26     pequen ilh caval brav sufici compet corr escor...
# 27     livr format bols ilustr rua traz compil pi pub...
# 28     uni sent cat acab ouv convers sigil poder tom ...
# 29     mant cas esp cativ cas tímid herd dev fic surp...
# ...                                                  ...
# 10140  nov rum vizinhanç cheg mulh mís vident diz ser...
# 10141  livr histór inúmer improv person junt pass bat...
# 10142  encontr relat milagr atravess long percurs cac...
# 10143  pal morr acid carr prim cois sent própr surpr ...
# 10144  alt ruír templ perd are temp relig antig despa...
# 10145  unicórni menin vent junt veloc charl ano grit ...
# 10146  revolt popul golp milit guerr civil rebel polí...
# 10147  tin am herol animal fant habit volt arqu mag i...
# 10148  cor escr plant algod déc conhec vid companh ou...
# 10149  conhec popul canal culinár une pesso mund volt...
# 10150  temp difícel urg entend mund quest perturb con...
# 10151  livr premi autor apresent séri cois pegaj deix...
# 10152  cont torn element fundament evoluç mit lend pr...
# 10153  nov ediç fam livr record mund encontr record a...
# 10154  guerr am vid un dram sens visit lembranç segun...
# 10155  lind cadel vir lat adot luc opç alegr cachorr ...
# 10156  holocaust segund guerr mund moment decis histó...
# 10157  sab girl chanc aproxim tri vai fic sab nasc ba...
# 10158  adiant engan ano começ carnav consegu difícil ...
# 10159  ad coloc olh doc esper fic fascin man inexplic...
# 10160  grand barulh eco redor mund traz cao confus at...
# 10161  amorim cresc pequen cidad and pequen apaixon t...
# 10162  livr conhec escri apresent séri cois assust pr...
# 10163  dr especi neozeland saúd mulh foc trabalh cur ...
# 10164  vid col gir torn hóq soub cresc jog sonh ser c...
# 10165  grit vitór dor olh extasi fim enxerg vazi olh ...
# 10166  qu ter própr vid qu esquec dia tragéd fog pânt...
# 10167  am compartilh tip esquec tip qu esquec far coi...
# 10168  sab imprens capaz faz vid intrig boat ment des...
# 10169  livr envolv tem emocion far coraçã aceler dand...
#
# [10170 rows x 18 columns]
