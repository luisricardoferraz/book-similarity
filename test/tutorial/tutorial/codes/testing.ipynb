# %%
#! pip install googletrans
import re
from string import punctuation
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import RSLPStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import requests

import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
texto1 = "Ele achava que o c\u00e3o era imortal. Assim come\u00e7a a vasta, poderosa e comovente narrativa de Susan Orlean sobre a jornada de Rin Tin Tin \u2013 de sobrevivente \u00f3rf\u00e3o a astro do cinema e \u00edcone internacional do showbiz.Suzan, redatora da New Yorker chamada de \u201cpatrim\u00f4nio nacional\u201d pelo Washington Post, passou cerca de dez anos pesquisando e escrevendo sua mais cativante obra: a hist\u00f3ria de um c\u00e3o que nasceu em 1.918 e nunca morreu. A narrativa come\u00e7a num campo de batalha franc\u00eas da Primeira Guerra Mundial, quando Lee Duncan, um jovem soldado americano, descobre um sobrevivente: um pastor-alem\u00e3o rec\u00e9m-nascido nas ru\u00ednas de um canil bombardeado. Para Duncan, que passou parte da inf\u00e2ncia num orfanato, a sobreviv\u00eancia do c\u00e3o fora um milagre. Havia algo em Rin Tin Tin que o compelia a compartilh\u00e1-lo com o mundo. Duncan o levou, ent\u00e3o, para a Calif\u00f3rnia, onde suas aptid\u00f5es f\u00edsicas e a capacidade de representar chamaram a aten\u00e7\u00e3o da Warner Bros. Durante os dez anos seguintes, Rinty estrelou 23 sucessos do cinema mudo que salvaram o est\u00fadio da fal\u00eancia e fizeram dele o c\u00e3o mais famoso de todos os tempos. No auge da popularidade, Rin Tin Tin foi o campe\u00e3o de bilheteria de Hollywood. Ao longo das d\u00e9cadas seguintes, Rinty e seus descendentes fizeram a conturbada jornada do cinema mudo ao falado, do preto e branco \u00e0 cor, do r\u00e1dio \u00e0 televis\u00e3o, culminando no seriado de TV As Aventuras de Rin-Tin-Tin, um dos mais populares programas da \u00e9poca do baby boom. O legado do c\u00e3o her\u00f3i foi consolidado por Duncan e alguns outros \u2013 como Bert Leonard, o produtor do seriado da TV, e Daphne Hereford, a propriet\u00e1ria do atual Rin Tin Tin \u2013, que dedicaram a vida para assegurar a imortalidade da lenda. Na ess\u00eancia de Rin Tin Tin \u2013 a Vida e a Lenda h\u00e1 um tocante estudo do duradouro v\u00ednculo entre os humanos e os animais. Mas o livro \u00e9 tamb\u00e9m uma hist\u00f3ria ricamente matizada da ind\u00fastria do entretenimento e do empreendedorismo no s\u00e9culo XX. Abarcando um per\u00edodo de 90 anos, ele aborda a mudan\u00e7a de status dos c\u00e3es, de ajudantes em fazendas a membros diletos das fam\u00edlias urbanas, da origem do treinamento para a obedi\u00eancia \u00e0 evolu\u00e7\u00e3o gen\u00e9tica das ra\u00e7as, da ascens\u00e3o de Hollywood ao passado e presente dos c\u00e3es de guerra. Rico de humor e emo\u00e7\u00e3o, repleto de momentos que certamente levar\u00e3o o leitor \u00e0s l\u00e1grimas, Rin Tin Tin fez parte da prestigiad\u00edssima lista dos 100 MELHORES LIVROS DO ANO do New York Times, principalmente por ser uma mescla irresist\u00edvel de hist\u00f3ria, humanismo e maestria narrativa \u2013 espl\u00eandida celebra\u00e7\u00e3o de um grande \u00edcone universal por uma das mais talentosas escritoras da atualidade."

# %%
texto2 = "\"\"RESGATE\"\" Foi a primeira palavra que ouvi quando os tiros cessaram. ""ELE ESTÁ FERIDO, TIRE-O DAQUI!"" Foi o que ouvi quando fui levado para cima. ""ARRANQUE ISSO DELE"" Foi a última coisa que ouvi antes de me render a escuridão. Uma década depois e essas palavras ainda permeiam meus pensamentos. Antes, elas me causavam medo, mas aprendi a lidar com ele. Transformei o medo em ódio, em uma motivação. O combustível que precisava e a justificativa perfeita para a escuridão dentro de mim. Hoje eu tenho um plano, e não vou desviar, nem que isso signifique silenciar a única voz capaz de acalmar os demônios na minha cabeça danificada. Eles roubaram a minha vida, e não a quero de volta. Meu único desejo é acabar com a deles."

# %%
texto3 = "Feyre has returned to the Spring Court, determined to gather information on Tamlin's maneuverings and the invading king threatening to bring Prythian to its knees. But to do so she must play a deadly game of deceit-and one slip may spell doom not only for Feyre, but for her world as well. As war bears down upon them all, Feyre must decide who to trust amongst the dazzling and lethal High Lords-and hunt for allies in unexpected places. In this thrilling third book in the #1 New York Times and USA Today bestselling series from Sarah J. Maas, the earth will be painted red as mighty armies grapple for power over the one thing that could destroy them all."

# %%
textos = [texto1,texto2,texto3]

# %%
st = RSLPStemmer()

# %%
text = "uma jovem garota brasileira resolve se aventurar em um curso de inglês no exterior na poderosa la em meio ao itinerário de passeios mesclados com estudos ela se vê em um torvelinho de emoções ao conhecer subitamente um astro em ascensão do cinema seus passeios acabam sendo mais intensos do que poderia sequer sonhar ela se vê no poderoso mundo das celebridades onde o glamour pode deslumbrar ou ofuscar seus ideais o mais importante porém seria ela capaz de manter um romance onde os holofotes nunca se apagavam "
text2 = "jovem garota brasileira resolve aventurar curso inglês exterior poderosa la meio itinerário passeios mesclados estudos vê torvelinho emoções conhecer subitamente astro ascensão cinema passeios acabam sendo intensos poderia sequer sonhar vê poderoso mundo celebridades onde glamour pode deslumbrar ofuscar ideais importante porém capaz manter romance onde holofotes nunca apagavam"

stopwordsList = stopwords.words('portuguese')

def requestPosTagging(text):
    try:
        payload = {'texto': str(text)}
        response = requests.get('http://portservice.pythonanywhere.com/analise/morfossintatica/freeling', params=payload).json()
    except:
        print(text)
    return response

def removeStopwordsFromSynopsis(text):
    tokens = word_tokenize(text)
    synopsisWithoutStopwords = [word for word in tokens if word not in stopwordsList]
    return " ".join(synopsisWithoutStopwords)


def applyStemmingOnSynopsis(text):
    stringAfterStemming = []
    for token in word_tokenize(text):
        stringAfterStemming.append(st.stem(token))
    return " ".join(stringAfterStemming)

print(text)
print('\n')
synopsisWithoutStopwords = removeStopwordsFromSynopsis(text)
print(synopsisWithoutStopwords)
print('\n')
print(applyStemmingOnSynopsis(synopsisWithoutStopwords))

print('\n')
print(len(requestPosTagging(text)))
print(str(requestPosTagging(text)))
print('\n')
print(len(requestPosTagging(text2)))
print(str(requestPosTagging(text2)))
# Out:
# uma jovem garota brasileira resolve se aventurar em um curso de inglês no exterior na poderosa la em meio ao itinerário de passeios mesclados com estudos ela se vê em um torvelinho de emoções ao conhecer subitamente um astro em ascensão do cinema seus passeios acabam sendo mais intensos do que poderia sequer sonhar ela se vê no poderoso mundo das celebridades onde o glamour pode deslumbrar ou ofuscar seus ideais o mais importante porém seria ela capaz de manter um romance onde os holofotes nunca se apagavam
#
#
# jovem garota brasileira resolve aventurar curso inglês exterior poderosa la meio itinerário passeios mesclados estudos vê torvelinho emoções conhecer subitamente astro ascensão cinema passeios acabam sendo intensos poderia sequer sonhar vê poderoso mundo celebridades onde glamour pode deslumbrar ofuscar ideais importante porém capaz manter romance onde holofotes nunca apagavam
#
#
# jov garot brasil resolv aventur curs ingl exteri poder la mei itiner passei mescl estud vê torvel emoç conhec subit astr ascens cinem passei acab send intens pod sequ sonh vê poder mund celebr ond glamour pod deslumbr ofusc ideal import porém capaz mant romanc ond holofot nunc apag
#
#
# 96
# [{'poss': 'DI0', 'lemma': 'um', 'token': 'uma'}, {'poss': 'AQ0', 'lemma': 'jovem', 'token': 'jovem'}, {'poss': 'NCFS', 'lemma': 'garoto', 'token': 'garota'}, {'poss': 'AQ0', 'lemma': 'brasileiro', 'token': 'brasileira'}, {'poss': 'VMI', 'lemma': 'resolver', 'token': 'resolve'}, {'poss': 'PP3', 'lemma': 'se', 'token': 'se'}, {'poss': 'VMN', 'lemma': 'aventurar', 'token': 'aventurar'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'DI0', 'lemma': 'um', 'token': 'um'}, {'poss': 'NCMS', 'lemma': 'curso', 'token': 'curso'}, {'poss': 'SPS', 'lemma': 'de', 'token': 'de'}, {'poss': 'NCMS', 'lemma': 'inglês', 'token': 'inglês'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'o'}, {'poss': 'NCMS', 'lemma': 'exterior', 'token': 'exterior'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'a'}, {'poss': 'NCFS', 'lemma': 'poderoso', 'token': 'poderosa'}, {'poss': 'PP3', 'lemma': 'o', 'token': 'la'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'NCMS', 'lemma': 'meio', 'token': 'meio'}, {'poss': 'SPS', 'lemma': 'a', 'token': 'a'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'o'}, {'poss': 'NCMS', 'lemma': 'itinerário', 'token': 'itinerário'}, {'poss': 'SPS', 'lemma': 'de', 'token': 'de'}, {'poss': 'NCMP', 'lemma': 'passeio', 'token': 'passeios'}, {'poss': 'VMP', 'lemma': 'mesclar', 'token': 'mesclados'}, {'poss': 'SPS', 'lemma': 'com', 'token': 'com'}, {'poss': 'NCMP', 'lemma': 'estudo', 'token': 'estudos'}, {'poss': 'PP3', 'lemma': 'ele', 'token': 'ela'}, {'poss': 'PP3', 'lemma': 'se', 'token': 'se'}, {'poss': 'VMI', 'lemma': 'ver', 'token': 'vê'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'DI0', 'lemma': 'um', 'token': 'um'}, {'poss': 'NCMS', 'lemma': 'torvelinho', 'token': 'torvelinho'}, {'poss': 'SPS', 'lemma': 'de', 'token': 'de'}, {'poss': 'NCFP', 'lemma': 'emoção', 'token': 'emoções'}, {'poss': 'SPS', 'lemma': 'a', 'token': 'a'}, {'poss': 'PP3', 'lemma': 'o', 'token': 'o'}, {'poss': 'VMN', 'lemma': 'conhecer', 'token': 'conhecer'}, {'poss': 'RG', 'lemma': 'subitamente', 'token': 'subitamente'}, {'poss': 'DI0', 'lemma': 'um', 'token': 'um'}, {'poss': 'NCMS', 'lemma': 'astro', 'token': 'astro'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'NCFS', 'lemma': 'ascensão', 'token': 'ascensão'}, {'poss': 'SPS', 'lemma': 'de', 'token': 'de'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'o'}, {'poss': 'NCMS', 'lemma': 'cinema', 'token': 'cinema'}, {'poss': 'PX3', 'lemma': 'seu', 'token': 'seus'}, {'poss': 'NCMP', 'lemma': 'passeio', 'token': 'passeios'}, {'poss': 'VMI', 'lemma': 'acabar', 'token': 'acabam'}, {'poss': 'VMG', 'lemma': 'ser', 'token': 'sendo'}, {'poss': 'RG', 'lemma': 'mais', 'token': 'mais'}, {'poss': 'AQ0', 'lemma': 'intenso', 'token': 'intensos'}, {'poss': 'SPS', 'lemma': 'de', 'token': 'de'}, {'poss': 'PD0', 'lemma': 'o', 'token': 'o'}, {'poss': 'PR0', 'lemma': 'que', 'token': 'que'}, {'poss': 'VMI', 'lemma': 'poder', 'token': 'poderia'}, {'poss': 'RG', 'lemma': 'sequer', 'token': 'sequer'}, {'poss': 'VMN', 'lemma': 'sonhar', 'token': 'sonhar'}, {'poss': 'PP3', 'lemma': 'ele', 'token': 'ela'}, {'poss': 'PP3', 'lemma': 'se', 'token': 'se'}, {'poss': 'VMI', 'lemma': 'ver', 'token': 'vê'}, {'poss': 'SPS', 'lemma': 'em', 'token': 'em'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'o'}, {'poss': 'AQ0', 'lemma': 'poderoso', 'token': 'poderoso'}, {'poss': 'NCMS', 'lemma': 'mundo', 'token': 'mundo'}, {'poss': 'SPS', 'lemma': 'de', 'token': 'de'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'as'}, {'poss': 'NCCP', 'lemma': 'celebridade', 'token': 'celebridades'}, {'poss': 'RG', 'lemma': 'onde', 'token': 'onde'}, {'poss': 'DA0', 'lemma': 'o', 'token': 'o'}, {'poss': 'NCFS', 'lemma': 'glamour', 'token': 'glamour'}, {'poss': 'VMI', 'lemma': 'poder', 'token': 'pode'}, {'poss': 'VMN', 'lemma': 'deslumbrar', 'token': 'deslumbrar'}, {'poss': 'CC', 'lemma': 'ou', 'token': 'ou'}, {'poss': 'VMN', 'lemma': 'ofuscar', 'token': 'ofuscar'}, {'pos ...
#
#
# 49
# [{'poss': 'AQ0', 'lemma': 'jovem', 'token': 'jovem'}, {'poss': 'NCFS', 'lemma': 'garoto', 'token': 'garota'}, {'poss': 'AQ0', 'lemma': 'brasileiro', 'token': 'brasileira'}, {'poss': 'VMI', 'lemma': 'resolver', 'token': 'resolve'}, {'poss': 'VMN', 'lemma': 'aventurar', 'token': 'aventurar'}, {'poss': 'NCMS', 'lemma': 'curso', 'token': 'curso'}, {'poss': 'AQ0', 'lemma': 'inglês', 'token': 'inglês'}, {'poss': 'NCMS', 'lemma': 'exterior', 'token': 'exterior'}, {'poss': 'AQ0', 'lemma': 'poderoso', 'token': 'poderosa'}, {'poss': 'PP3', 'lemma': 'o', 'token': 'la'}, {'poss': 'RG', 'lemma': 'meio', 'token': 'meio'}, {'poss': 'AQ0', 'lemma': 'itinerário', 'token': 'itinerário'}, {'poss': 'NCMP', 'lemma': 'passeio', 'token': 'passeios'}, {'poss': 'VMP', 'lemma': 'mesclar', 'token': 'mesclados'}, {'poss': 'NCMP', 'lemma': 'estudo', 'token': 'estudos'}, {'poss': 'VMI', 'lemma': 'ver', 'token': 'vê'}, {'poss': 'NCMS', 'lemma': 'torvelinho', 'token': 'torvelinho'}, {'poss': 'NCFP', 'lemma': 'emoção', 'token': 'emoções'}, {'poss': 'VMN', 'lemma': 'conhecer', 'token': 'conhecer'}, {'poss': 'RG', 'lemma': 'subitamente', 'token': 'subitamente'}, {'poss': 'NCMS', 'lemma': 'astro', 'token': 'astro'}, {'poss': 'NCFS', 'lemma': 'ascensão', 'token': 'ascensão'}, {'poss': 'NCMS', 'lemma': 'cinema', 'token': 'cinema'}, {'poss': 'NCMP', 'lemma': 'passeio', 'token': 'passeios'}, {'poss': 'VMI', 'lemma': 'acabar', 'token': 'acabam'}, {'poss': 'VMG', 'lemma': 'ser', 'token': 'sendo'}, {'poss': 'AQ0', 'lemma': 'intenso', 'token': 'intensos'}, {'poss': 'VMI', 'lemma': 'poder', 'token': 'poderia'}, {'poss': 'RG', 'lemma': 'sequer', 'token': 'sequer'}, {'poss': 'VMN', 'lemma': 'sonhar', 'token': 'sonhar'}, {'poss': 'VMI', 'lemma': 'ver', 'token': 'vê'}, {'poss': 'AQ0', 'lemma': 'poderoso', 'token': 'poderoso'}, {'poss': 'NCMS', 'lemma': 'mundo', 'token': 'mundo'}, {'poss': 'NCCP', 'lemma': 'celebridade', 'token': 'celebridades'}, {'poss': 'RG', 'lemma': 'onde', 'token': 'onde'}, {'poss': 'NCFS', 'lemma': 'glamour', 'token': 'glamour'}, {'poss': 'VMI', 'lemma': 'poder', 'token': 'pode'}, {'poss': 'VMN', 'lemma': 'deslumbrar', 'token': 'deslumbrar'}, {'poss': 'VMN', 'lemma': 'ofuscar', 'token': 'ofuscar'}, {'poss': 'NCMP', 'lemma': 'ideal', 'token': 'ideais'}, {'poss': 'AQ0', 'lemma': 'importante', 'token': 'importante'}, {'poss': 'CC', 'lemma': 'porém', 'token': 'porém'}, {'poss': 'AQ0', 'lemma': 'capaz', 'token': 'capaz'}, {'poss': 'VMN', 'lemma': 'manter', 'token': 'manter'}, {'poss': 'NCMS', 'lemma': 'romance', 'token': 'romance'}, {'poss': 'RG', 'lemma': 'onde', 'token': 'onde'}, {'poss': 'NCMP', 'lemma': 'holofote', 'token': 'holofotes'}, {'poss': 'RG', 'lemma': 'nunca', 'token': 'nunca'}, {'poss': 'VMI', 'lemma': 'apagar', 'token': 'apagavam'}]

# %%
filePath = 'C:/Users/LuisRicardoFerraz/Documents/personal/projects/book-similarity/test/tutorial/tutorial/spiders/synopsis-preprocessing/'
df = pd.read_csv(filePath+'testingPosTagging.csv')
df = df.drop(['Unnamed: 0'],1)
df
# Out:
#           isbn-10       isbn-13  \
# 0      8552923262  9.788550e+12
# 1      8552923440  9.788550e+12
# 2      8552923157  9.788550e+12
# 3      1408857901  9.781410e+12
# 4      855292336X  9.788550e+12
# 5      8580418895  9.788580e+12
# 6      8552923394  9.788550e+12
# 7      8576865238  9.788580e+12
# 8      8565859150  9.788570e+12
# 9      8501401439  9.788500e+12
# 10     000022460X  4.870000e+12
# 11     8580416701  9.788580e+12
# 12     854410553X  9.788540e+12
# 13     854410651X  9.788540e+12
# 14     8576864517  9.788580e+12
# 15     8580417465  9.788580e+12
# 16     8544105327  9.788540e+12
# 17     8539825384  9.788540e+12
# 18     8576863227  9.788580e+12
# 19     8542212312  9.788540e+12
# 20     8544104223  9.788540e+12
# 21     8576863413  9.788580e+12
# 22     8539823659  9.788540e+12
# 23     8539823624  9.788540e+12
# 24     8576862026  9.788580e+12
# 25     8576862131  9.788580e+12
# 26     8539822229  9.788540e+12
# 27     8576861844  9.788580e+12
# 28     857686181X  9.788580e+12
# 29     8539822318  9.788540e+12
# ...           ...           ...
# 10269  8595082774  9.788600e+12
# 10270  8595082065  9.788600e+12
# 10271  8595083363  9.788600e+12
# 10272  8595080984  9.788600e+12
# 10273  8595082316  9.788600e+12
# 10274  8595083258  9.788600e+12
# 10275  8595082332  9.788600e+12
# 10276  8595083355  9.788600e+12
# 10277  8595082952  9.788600e+12
# 10278  8595083967  9.788600e+12
# 10279  8595082340  9.788600e+12
# 10280  8595083320  9.788600e+12
# 10281  8595083665  9.788600e+12
# 10282  8595083282  9.788600e+12
# 10283  8595083614  9.788600e+12
# 10284  859508470X  9.788600e+12
# 10285  8595082901  9.788600e+12
# 10286  8595083762  9.788600e+12
# 10287  8552923076  9.788550e+12
# 10288  8552923025  9.788550e+12
# 10289  859508467X  9.788600e+12
# 10290  8595083754  9.788600e+12
# 10291  8595083312  9.788600e+12
# 10292  8595083819  9.788600e+12
# 10293  8552923033  9.788550e+12
# 10294  8552923106  9.788550e+12
# 10295  8552923343  9.788550e+12
# 10296  8552923475  9.788550e+12
# 10297  8552923459  9.788550e+12
# 10298  8552923300  9.788550e+12
#
#                                                   titulo  \
# 0                                        Tapete Vermelho
# 1                                                 Hunter
# 2                                                   Cage
# 3                              A Court of Wings and Ruin
# 4                                         Espere Por Mim
# 5                                                    Vox
# 6                                                   Ayra
# 7                                         Amor Plus Size
# 8                                          O Sal da Vida
# 9                                                Aliança
# 10                                   A Dança dos Dragões
# 11                                  Diário de Uma Paixão
# 12                                       Luta de Valetes
# 13                                      Mulher-Maravilha
# 14                                Onde o Amor Se Esconde
# 15                  Mulher-Maravilha: Sementes da Guerra
# 16                                    Todos contra todos
# 17                       A Verdade Sobre Amores e Duques
# 18                        As Batidas Perdidas do Coração
# 19                                 A batalha das Ardenas
# 20                                  Churchill - Uma vida
# 21                     O Diário Secreto de Lizzie Bennet
# 22                            Cartas Para Uma Falsa Dama
# 23                                        Falsas Imagens
# 24                                      Dezenove Minutos
# 25                                        Encanto Mortal
# 26                                  Sintonia de Corações
# 27                                A Corrida de Escorpião
# 28                                          Piadas Nerds
# 29                                   Natureza Apaixonada
# ...                                                  ...
# 10269                                    Os Imortalistas
# 10270                     1565: Enquanto o Brasil Nascia
# 10271                                    Procurando Gobi
# 10272                      O Mau Exemplo de Cameron Post
# 10273                         Livro de Ouro da Mitologia
# 10274                       Um Planeta em Seu Giro Veloz
# 10275                     O Livro de Ouro das Revoluções
# 10276                               Os Arquivos da Magia
# 10277  The Underground Railroad: Os Caminhos Para a L...
# 10278                        Tasty. As Melhores Receitas
# 10279                                    A Arte de Viver
# 10280                                 Coisas Melequentas
# 10281                                    Beren e Lúthien
# 10282                        Guinness World Records 2019
# 10283                           As Madonas de Leningrado
# 10284                                  A Caminho de Casa
# 10285                      1924 - O Ano Que Criou Hitler
# 10286     Bff Girls - O Começo De Uma História Pra Ficar
# 10287                               Cuida do meu coração
# 10288                                    Apenas um Toque
# 10289                                            Aaahhh!
# 10290                                     Maquiagem Teen
# 10291                                 Coisas Arrepiantes
# 10292                 O guia definitivo para o pós-parto
# 10293                                             Use-Me
# 10294                                  Inexplicável Amor
# 10295                                         Libertados
# 10296                                          Renegados
# 10297                                   Por Trás da Fama
# 10298                                          Para Você
#
#                                                  sinopse  adjective  \
# 0      uma jovem garota brasileira resolve se aventur...          6
# 1      resgate foi a primeira palavra que ouvi quando...          6
# 2      cage substantivo cela prisão verbo prender enj...          5
# 3      feyre has returned te o the spring court deter...          0
# 4      quebrado irritado abandonado era assim que ton...          5
# 5      uma distopia atual próxima de os dias de hoje ...          4
# 6      as histórias de contos de fadas que as criança...          2
# 7      maitê passos é uma garota linda de dezessete a...         11
# 8      existe uma forma de leveza e de graça em o sim...         12
# 9      um thriller sobre a luta secreta entre o bem e...          9
# 10     as crônicas de gelo e fogo jon snow daenerys t...          0
# 11     duke é um homem simples com uma vida modesta m...          0
# 12     o oitavo volume de wild cards injeta ainda mai...          0
# 13     diana prince mais conhecida como mulher maravi...          0
# 14     na são paulo do início do século xx a jovem gl...          0
# 15     antes de se tornar a mulher maravilha ela era ...          0
# 16     podemos até não viver no paraíso mas passamos ...          0
# 17     henry cavanaugh duque de torquil anseia por um...          0
# 18     viviane acaba de perder o pai com a mãe em dep...          0
# 19     nas primeiras horas do dia de dezembro de hitl...          0
# 20     escrito pelo biógrafo oficial de churchill o h...          0
# 21     lizzie bennet é uma jovem estudante de comunic...          0
# 22     ainda recém casado o conde tristan deixou sua ...          0
# 23     autoras best seller do usa today melodia do co...          0
# 24     sterling é uma cidadezinha comum do interior o...          0
# 25     o passado de mirabelle está envolto em segredo...          0
# 26     uma receita apaixonante pegue uma dose de magg...          0
# 27     na pequena ilha de thisby poucos cavaleiros sã...          0
# 28     livro em formato de bolso e com ilustrações de...          0
# 29     união de sentimentos anna cleary cate summerfi...          0
# ...                                                  ...        ...
# 10269  é no lower east side de nova york e os rumores...          0
# 10270  este livro é a história dos inúmeros e imprová...          0
# 10271  encontrando gobi é o relato milagroso de dion ...          0
# 10272  quando os pais de cameron post morrem em um ac...          0
# 10273  altares ruíram e templos se perderam nas areia...          0
# 10274  um unicórnio um menino e o vento juntos em uma...          0
# 10275  de revoltas populares a golpes militares de gu...          0
# 10276  newt tina queenie e jacob os amados heróis de ...          0
# 10277  cora é escrava em uma plantação de algodão da ...          0
# 10278  você conhece o tasty o popular canal de culiná...          0
# 10279  em tempos difíceis há uma urgência de entender...          0
# 10280  neste livro o premiado autor ilan brenman apre...          0
# 10281  o conto de beren e lúthien foi ou tornou se el...          0
# 10282  nova edição do guinness world records o mais f...          0
# 10283  guerra amor e vida se unem neste drama profund...          0
# 10284  bella uma linda cadelinha vira lata adotou luc...          0
# 10285  antes do holocausto e da segunda guerra mundia...          0
# 10286  você já sabe tudo sobre as bff girls não então...          0
# 10287  não adianta se enganar o ano só começa mesmo d...          0
# 10288   quando adam st james colocou os olhos na doce...          0
# 10289   um grande barulho ecoou ao redor do mundo tra...          0
# 10290  ramon amorim cresceu na pequena cidade de ando...          0
# 10291  neste livro o conhecido escritor ilan brenman ...          0
# 10292  o dr oscar serrallach é um especialista neozel...          0
# 10293  a vida de rhys cole sempre girou em torno do h...          0
# 10294  nunca era um grito de vitória mas sim de dor t...          0
# 10295  sawyer quer ter a própria vida finn quer esque...          0
# 10296  o amor que o finn e eu compartilhamos é do tip...          0
# 10297  james bradley sabia o que imprensa era capaz d...          0
# 10298  neste livro você será envolvido por temas emoc...          0
#
#        conjunction  determiner  noun  pronoun  adverb  adposition  verb  \
# 0                2          15    21       12       7          17    16
# 1                7          21    23       19      11          15    31
# 2                6          14    21        9      10          11    26
# 3                0          15     9        7       0           5     8
# 4                8          19    19       20       9          26    30
# 5                8          18    25        5      11          14    25
# 6                9          10    17       17      13          16    26
# 7                8          23    28        3       6          18    16
# 8               11          25    26       14      10          24    17
# 9                7          16    23        6       4          15    15
# 10               0           0     0        0       0           0     0
# 11               0           0     0        0       0           0     0
# 12               0           0     0        0       0           0     0
# 13               0           0     0        0       0           0     0
# 14               0           0     0        0       0           0     0
# 15               0           0     0        0       0           0     0
# 16               0           0     0        0       0           0     0
# 17               0           0     0        0       0           0     0
# 18               0           0     0        0       0           0     0
# 19               0           0     0        0       0           0     0
# 20               0           0     0        0       0           0     0
# 21               0           0     0        0       0           0     0
# 22               0           0     0        0       0           0     0
# 23               0           0     0        0       0           0     0
# 24               0           0     0        0       0           0     0
# 25               0           0     0        0       0           0     0
# 26               0           0     0        0       0           0     0
# 27               0           0     0        0       0           0     0
# 28               0           0     0        0       0           0     0
# 29               0           0     0        0       0           0     0
# ...            ...         ...   ...      ...     ...         ...   ...
# 10269            0           0     0        0       0           0     0
# 10270            0           0     0        0       0           0     0
# 10271            0           0     0        0       0           0     0
# 10272            0           0     0        0       0           0     0
# 10273            0           0     0        0       0           0     0
# 10274            0           0     0        0       0           0     0
# 10275            0           0     0        0       0           0     0
# 10276            0           0     0        0       0           0     0
# 10277            0           0     0        0       0           0     0
# 10278            0           0     0        0       0           0     0
# 10279            0           0     0        0       0           0     0
# 10280            0           0     0        0       0           0     0
# 10281            0           0     0        0       0           0     0
# 10282            0           0     0        0       0           0     0
# 10283            0           0     0        0       0           0     0
# 10284            0           0     0        0       0           0     0
# 10285            0           0     0        0       0           0     0
# 10286            0           0     0        0       0           0     0
# 10287            0           0     0        0       0           0     0
# 10288            0           0     0        0       0           0     0
# 10289            0           0     0        0       0           0     0
# 10290            0           0     0        0       0           0     0
# 10291            0           0     0        0       0           0     0
# 10292            0           0     0        0       0           0     0
# 10293            0           0     0        0       0           0     0
# 10294            0           0     0        0       0           0     0
# 10295            0           0     0        0       0           0     0
# 10296            0           0     0        0       0           0     0
# 10297            0           0     0        0       0           0     0
# 10298            0           0     0        0       0           0     0
#
#        number  date  interjection  punctuation  unknown  total
# 0           0     0             0            0        0     96
# 1           0     0             0            0        0    133
# 2           0     0             0            0        2    104
# 3           0     0             0            0       84    128
# 4           0     0             0            0        4    140
# 5           1     0             0            0        5    116
# 6           1     0             0            0        0    111
# 7           1     0             0            0        9    123
# 8           0     0             0            0        3    142
# 9           0     0             0            0        3     98
# 10          0     0             0            0        0      0
# 11          0     0             0            0        0      0
# 12          0     0             0            0        0      0
# 13          0     0             0            0        0      0
# 14          0     0             0            0        0      0
# 15          0     0             0            0        0      0
# 16          0     0             0            0        0      0
# 17          0     0             0            0        0      0
# 18          0     0             0            0        0      0
# 19          0     0             0            0        0      0
# 20          0     0             0            0        0      0
# 21          0     0             0            0        0      0
# 22          0     0             0            0        0      0
# 23          0     0             0            0        0      0
# 24          0     0             0            0        0      0
# 25          0     0             0            0        0      0
# 26          0     0             0            0        0      0
# 27          0     0             0            0        0      0
# 28          0     0             0            0        0      0
# 29          0     0             0            0        0      0
# ...       ...   ...           ...          ...      ...    ...
# 10269       0     0             0            0        0      0
# 10270       0     0             0            0        0      0
# 10271       0     0             0            0        0      0
# 10272       0     0             0            0        0      0
# 10273       0     0             0            0        0      0
# 10274       0     0             0            0        0      0
# 10275       0     0             0            0        0      0
# 10276       0     0             0            0        0      0
# 10277       0     0             0            0        0      0
# 10278       0     0             0            0        0      0
# 10279       0     0             0            0        0      0
# 10280       0     0             0            0        0      0
# 10281       0     0             0            0        0      0
# 10282       0     0             0            0        0      0
# 10283       0     0             0            0        0      0
# 10284       0     0             0            0        0      0
# 10285       0     0             0            0        0      0
# 10286       0     0             0            0        0      0
# 10287       0     0             0            0        0      0
# 10288       0     0             0            0        0      0
# 10289       0     0             0            0        0      0
# 10290       0     0             0            0        0      0
# 10291       0     0             0            0        0      0
# 10292       0     0             0            0        0      0
# 10293       0     0             0            0        0      0
# 10294       0     0             0            0        0      0
# 10295       0     0             0            0        0      0
# 10296       0     0             0            0        0      0
# 10297       0     0             0            0        0      0
# 10298       0     0             0            0        0      0
#
# [10299 rows x 18 columns]

# %%
def identifySynopsisInForeignLanguages():
    i = 0
    while i < 10:
        
        threshold = 0.5
        if df['unknown'][i]/df['total'][i] > threshold:
            print(str(df['titulo'][i]) + ": " + str(df['sinopse'][i]))
            print('\n')

        i += 1

identifySynopsisInForeignLanguages()
# Out:
# A Court of Wings and Ruin: feyre has returned te o the spring court determined te o gather information on tamlin s maneuverings and the invading king threatening te o bring prythian te o its knees but te o de o so she must play a deadly game of deceit and one slip may spell doom not only for feyre but for her world as well as war bears down upon them all feyre must decide who te o trust amongst the dazzling and lethal high lords and hunt for allies in unexpected places in this thrilling third book in the new york times and usa today bestselling series from sarah j maas the earth will be painted red as mighty armies grapple for power over the one thing that could destroy them all
